# %% [markdown]
# # Data Cleaning

# %%
# First we will import the pandas and numpy libraries for further data cleaning.

# %%
import pandas as pd
import numpy as np

# %%
# 1.Data reading(for ".data" and ".csv" extension write "pd.read_csv" and for ".xlsx" extension write "pd.read_excel)
# Here the file is in .xlsx format, so we will be using "pd.read_excel" for the given excel file.

# %%
con=pd.read_excel(r"C:\Users\asus\Desktop\Consumer Behavior and Shopping Habits Dataset\shopping_behavior_updated(final).xlsx")
con
# Out:
#       Customer ID  Age  Gender Item Purchased     Category  \
# 0               1   55    Male         Blouse     Clothing
# 1               2   19    Male        Sweater     Clothing
# 2               3   50    Male          Jeans     Clothing
# 3               4   21    Male        Sandals     Footwear
# 4               5   45    Male         Blouse     Clothing
# ...           ...  ...     ...            ...          ...
# 3895         3896   40  Female         Hoodie     Clothing
# 3896         3897   52  Female       Backpack  Accessories
# 3897         3898   46  Female           Belt  Accessories
# 3898         3899   44  Female          Shoes     Footwear
# 3899         3900   52  Female        Handbag  Accessories
#
#       Purchase Amount (USD)       Location Size      Color  Season  \
# 0                        53       Kentucky    L       Gray  Winter
# 1                        64          Maine    L     Maroon  Winter
# ...

# %%
# 2.Renaming the first column so as to make it as the starting column by first removing the by default indexes and also renaming other columns where space is there.

# %%
con=con.rename(columns={'Customer ID':'Customer_ID','Item Purchased':'Item_purchased','Purchase Amount (USD)':'Purchase_amount_in_USD','Review Rating':'Review_Ratings','Subscription Status':'Subscription_Status','Shipping Type':'Shipping_Type','Discount Applied':'Discount_Applied','Promo Code Used':'Promo_Code_Used','Previous Purchases':'Previous_Purchases','Payment Method':'Payment_Method','Frequency of Purchases':'Frequency_of_Purchases'})
con
# Out:
#       Customer_ID  Age  Gender Item_purchased     Category  \
# 0               1   55    Male         Blouse     Clothing
# 1               2   19    Male        Sweater     Clothing
# 2               3   50    Male          Jeans     Clothing
# 3               4   21    Male        Sandals     Footwear
# 4               5   45    Male         Blouse     Clothing
# ...           ...  ...     ...            ...          ...
# 3895         3896   40  Female         Hoodie     Clothing
# 3896         3897   52  Female       Backpack  Accessories
# 3897         3898   46  Female           Belt  Accessories
# 3898         3899   44  Female          Shoes     Footwear
# 3899         3900   52  Female        Handbag  Accessories
#
#       Purchase_amount_in_USD       Location Size      Color  Season  \
# 0                         53       Kentucky    L       Gray  Winter
# 1                         64          Maine    L     Maroon  Winter
# ...

# %%
con=con.set_index('Customer_ID')
con
# Out:
#              Age  Gender Item_purchased     Category  Purchase_amount_in_USD  \
# Customer_ID
# 1             55    Male         Blouse     Clothing                      53
# 2             19    Male        Sweater     Clothing                      64
# 3             50    Male          Jeans     Clothing                      73
# 4             21    Male        Sandals     Footwear                      90
# 5             45    Male         Blouse     Clothing                      49
# ...          ...     ...            ...          ...                     ...
# 3896          40  Female         Hoodie     Clothing                      28
# 3897          52  Female       Backpack  Accessories                      49
# 3898          46  Female           Belt  Accessories                      33
# 3899          44  Female          Shoes     Footwear                      77
# 3900          52  Female        Handbag  Accessories                      81
#
# ...

# %%
con.head(10)
# Out:
#              Age Gender Item_purchased     Category  Purchase_amount_in_USD  \
# Customer_ID
# 1             55   Male         Blouse     Clothing                      53
# 2             19   Male        Sweater     Clothing                      64
# 3             50   Male          Jeans     Clothing                      73
# 4             21   Male        Sandals     Footwear                      90
# 5             45   Male         Blouse     Clothing                      49
# 6             46   Male       Sneakers     Footwear                      20
# 7             63   Male          Shirt     Clothing                      85
# 8             27   Male         Shorts     Clothing                      34
# 9             26   Male           Coat    Outerwear                      97
# 10            57   Male        Handbag  Accessories                      31
#
#                   Location Size      Color  Season  Review_Ratings  \
# Customer_ID
# ...

# %%
# 3.Checking Null Values if present or not

# %%
con.isnull().sum()
# Out:
# Age                       0
# Gender                    0
# Item_purchased            0
# Category                  0
# Purchase_amount_in_USD    0
# Location                  0
# Size                      0
# Color                     0
# Season                    0
# Review_Ratings            0
# Subscription_Status       0
# Shipping_Type             0
# Discount_Applied          0
# Promo_Code_Used           0
# Previous_Purchases        0
# Payment_Method            0
# Frequency_of_Purchases    0
# dtype: int64

# %%
# 4.Checking dtypes

# %%
con.dtypes
# Out:
# Age                         int64
# Gender                     object
# Item_purchased             object
# Category                   object
# Purchase_amount_in_USD      int64
# Location                   object
# Size                       object
# Color                      object
# Season                     object
# Review_Ratings            float64
# Subscription_Status        object
# Shipping_Type              object
# Discount_Applied           object
# Promo_Code_Used            object
# Previous_Purchases          int64
# Payment_Method             object
# Frequency_of_Purchases     object
# dtype: object

# %%
con.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3900 entries, 1 to 3900
# Data columns (total 17 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Age                     3900 non-null   int64
#  1   Gender                  3900 non-null   object
#  2   Item_purchased          3900 non-null   object
#  3   Category                3900 non-null   object
#  4   Purchase_amount_in_USD  3900 non-null   int64
#  5   Location                3900 non-null   object
#  6   Size                    3900 non-null   object
#  7   Color                   3900 non-null   object
#  8   Season                  3900 non-null   object
#  9   Review_Ratings          3900 non-null   float64
#  10  Subscription_Status     3900 non-null   object
#  11  Shipping_Type           3900 non-null   object
#  12  Discount_Applied        3900 non-null   object
#  13  Promo_Code_Used         3900 non-null   object
# ...

# %%
# 5.Checking Unique Values

# %%
for i in con.columns:
    print(i,':','\n',con[i].unique())
# Out:
# Age :
#  [55 19 50 21 45 46 63 27 26 57 53 30 61 65 64 25 52 66 31 56 18 38 54 33
#  36 35 29 70 69 67 20 39 42 68 49 59 47 40 41 48 22 24 44 37 58 32 62 51
#  28 43 34 23 60]
# Gender :
#  ['Male' 'Female']
# Item_purchased :
#  ['Blouse' 'Sweater' 'Jeans' 'Sandals' 'Sneakers' 'Shirt' 'Shorts' 'Coat'
#  'Handbag' 'Shoes' 'Dress' 'Skirt' 'Sunglasses' 'Pants' 'Jacket' 'Hoodie'
#  'Jewelry' 'T-shirt' 'Scarf' 'Hat' 'Socks' 'Backpack' 'Belt' 'Boots'
#  'Gloves']
# Category :
#  ['Clothing' 'Footwear' 'Outerwear' 'Accessories']
# Purchase_amount_in_USD :
#  [ 53  64  73  90  49  20  85  34  97  31  68  72  51  81  36  38  48  62
#   37  88  22  25  56  94  79  67  91  33  69  45  60  76  39 100  21  43
#   54  55  30  28  59  24  83  46  70  29  26  58  96  40  32  95  41  47
#   99  87  92  98  89  35  75  65  86  84  77  27  23  74  80  42  61  82
#   78  93  50  57  66  44  52  71  63]
# Location :
#  ['Kentucky' 'Maine' 'Massachusetts' 'Rhode Island' 'Oregon' 'Wyoming'
# ...

# %%
# 6.Describing some parameters of data present in Columns

# %%
con.describe(include='all')
# Out:
#                 Age Gender Item_purchased  Category  Purchase_amount_in_USD  \
# count   3900.000000   3900           3900      3900             3900.000000
# unique          NaN      2             25         4                     NaN
# top             NaN   Male         Blouse  Clothing                     NaN
# freq            NaN   2652            171      1737                     NaN
# mean      44.068462    NaN            NaN       NaN               59.764359
# std       15.207589    NaN            NaN       NaN               23.685392
# min       18.000000    NaN            NaN       NaN               20.000000
# 25%       31.000000    NaN            NaN       NaN               39.000000
# 50%       44.000000    NaN            NaN       NaN               60.000000
# 75%       57.000000    NaN            NaN       NaN               81.000000
# max       70.000000    NaN            NaN       NaN              100.000000
#
# ...

# %%
# 7.Developing Meaningful Graphs Using Matplotlib And Seaborn

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sns.countplot(x='Gender',data=con)
plt.title("Gender Distribution")
plt.show()

# %%
sns.boxplot(x=con['Category'],y=con.Review_Ratings)
plt.show()

# %%
sns.kdeplot(data=con,x='Age',hue='Subscription_Status',fill=True)
plt.title('Customer Age Distribution by Subscription Status')
plt.xlabel('Age')
plt.ylabel('Density')
plt.show()
# Out:
# C:\Users\asus\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
sns.barplot(x='Category',y='Purchase_amount_in_USD',data=con,errorbar=None)
plt.title('Average Purchase Amount By Category')
plt.xlabel('Category')
plt.ylabel('Average Purchase Amount(USD)')
plt.show()

# %%
sns.histplot(con['Review_Ratings'],bins=10,kde=False)
plt.title('Review Ratings Distribution')
plt.xlabel('Review Rating')
plt.ylabel('Count')
plt.show()
# Out:
# C:\Users\asus\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
seasons=con['Season'].unique()
average_purchase_by_season=con.groupby('Season')['Purchase_amount_in_USD'].mean()
plt.bar(seasons, average_purchase_by_season, color=['Red', 'Violet', 'Pink', 'Green'])
plt.title("Impact of Season on Purchase")
plt.xlabel("Season")
plt.ylabel("Average Purchase (USD)")
plt.show()

# %%
counts= con['Promo_Code_Used'].value_counts()
plt.pie(counts, labels=counts.index, autopct='%1.1f%%', startangle=90, colors=['Blue','Red'])
plt.title("Impact of Promo Code Used while Purchasing")
plt.show()

# %%
location_counts=con["Location"].value_counts()
location_counts.plot(kind="bar",color="DarkViolet",figsize=(16,6))
plt.title("Customers Distribution by Location")
plt.xlabel("Location")
plt.ylabel("Number of Customers")
plt.show()

# %%
category_counts.
# Out:
# Category
# Clothing       1737
# Accessories    1240
# Footwear        599
# Outerwear       324
# Name: count, dtype: int64

# %%
category_counts.values
# Out:
# array([1737, 1240,  599,  324], dtype=int64)

# %%
category_counts = con['Category'].value_counts()
bars = plt.bar(category_counts.index, category_counts.values, color=['Red','Maroon','DarkBlue','Green'])
plt.xlabel('Categories')
plt.ylabel('Count')
plt.title('Distribution of Product Categories')
plt.show()

# %%
Shipping_counts = con['Shipping_Type'].value_counts()
Shipping_counts.plot(kind="bar",color=['DarkViolet','Red','Blue','Green','Black','Yellow'],figsize=(15,6))
plt.xlabel('Shipping Type')
plt.ylabel('Count')
plt.title('Distribution of Shipping Type')
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.countplot(x='Payment_Method',data=con)
plt.title("Payment Method Distribution")
plt.show()

# %%
plt.figure(figsize=(20, 6))
sns.boxplot(x=con['Item_purchased'],y=con.Review_Ratings)
plt.show()

# %% [markdown]
# # Machine Learning

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()

# %%
con.Gender = le.fit_transform(con.Gender)
con.Item_purchased = le.fit_transform(con.Item_purchased)
con.Location=le.fit_transform(con.Location)
con.Size=le.fit_transform(con.Size)
con.Color=le.fit_transform(con.Color)
con.Season=le.fit_transform(con.Season)
con.Subscription_Status=le.fit_transform(con.Subscription_Status)
con.Shipping_Type=le.fit_transform(con.Shipping_Type)
con.Discount_Applied=le.fit_transform(con.Discount_Applied)
con.Promo_Code_Used=le.fit_transform(con.Promo_Code_Used)
con.Payment_Method=le.fit_transform(con.Payment_Method)
con.Frequency_of_Purchases=le.fit_transform(con.Frequency_of_Purchases)

# %%
ip=con.drop(['Subscription_Status','Category'],axis=1)
op=con.Subscription_Status

# %%
ip,op
# Out:
# (             Age  Gender  Item_purchased  Purchase_amount_in_USD  Location  \
#  Customer_ID
#  1             55       1               2                      53        16
#  2             19       1              23                      64        18
#  3             50       1              11                      73        20
#  4             21       1              14                      90        38
#  5             45       1               2                      49        36
#  ...          ...     ...             ...                     ...       ...
#  3896          40       0               9                      28        45
#  3897          52       0               0                      49        14
#  3898          46       0               1                      33        29
#  3899          44       0              17                      77        22
#  3900          52       0               7                      81         4
#
# ...

# %% [markdown]
# # Train_Test_Split

# %%
from sklearn.model_selection import train_test_split

# %%
xtr,xts,ytr,yts = train_test_split(ip,op,test_size=0.2,random_state=7)

# %%
xtr
# Out:
#              Age  Gender  Item_purchased  Purchase_amount_in_USD  Location  \
# Customer_ID
# 2877          65       0               9                      84        30
# 3823          70       0               8                      41        15
# 2766          64       0               6                      70         5
# 2789          56       0               3                      92        38
# 2752          27       0               5                      52        22
# ...          ...     ...             ...                     ...       ...
# 1604          23       1              18                      98        14
# 2551          53       1               3                      52        28
# 538           50       1               2                      49        45
# 1221          67       1               6                      64        16
# 176           53       1               4                      86        35
#
# ...

# %%
print(xtr.size,xts.size)
# Out:
# 46800 11700

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
xtr1 = sc.fit_transform(xtr)
xts1= sc.fit_transform(xts)

# %%
from sklearn.preprocessing import MinMaxScaler
mc = MinMaxScaler()
xtr2 = mc.fit_transform(xtr) 
xts2= mc.fit_transform(xts)

# %%
print(xtr,xts)
# Out:
#              Age  Gender  Item_purchased  Purchase_amount_in_USD  Location  \
# Customer_ID
# 2877          65       0               9                      84        30
# 3823          70       0               8                      41        15
# 2766          64       0               6                      70         5
# 2789          56       0               3                      92        38
# 2752          27       0               5                      52        22
# ...          ...     ...             ...                     ...       ...
# 1604          23       1              18                      98        14
# 2551          53       1               3                      52        28
# 538           50       1               2                      49        45
# 1221          67       1               6                      64        16
# 176           53       1               4                      86        35
#
# ...

# %%
ytr.unique()
# Out:
# array([0, 1])

# %%
from sklearn.linear_model import LogisticRegression
le=LogisticRegression()

# %%
le.fit(xtr1,ytr)
# Out:
# LogisticRegression()

# %%
y_pred = le.predict(xts1)

# %%
from sklearn.metrics import f1_score,recall_score,precision_score,accuracy_score
acc=accuracy_score(y_pred,yts)
pre=precision_score(y_pred,yts,average='macro')
rec = recall_score(y_pred,yts,average='macro')
f1 = f1_score(y_pred,yts,average='macro')
print('f1_score=',f1,'accuracy_score=',acc,'precision_score=',pre,'recall_score=',rec)
# Out:
# f1_score= 0.8212557926363497 accuracy_score= 0.8384615384615385 precision_score= 0.8902439024390244 recall_score= 0.8102409638554218

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay

# %%
cm=confusion_matrix(yts,y_pred)
cm
# Out:
# array([[448, 126],
#        [  0, 206]], dtype=int64)

# %%
cmd = ConfusionMatrixDisplay(cm)
cmd.plot()
plt.show()

# %% [markdown]
# # Naive Bayes

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
gnb.fit(xtr1,ytr)
# Out:
# GaussianNB()

# %%
gpred=gnb.predict(xts1)

# %%
gpred = gnb.predict(xts1)
cm2 = confusion_matrix(gpred,yts)
cm2
# Out:
# array([[574, 206],
#        [  0,   0]], dtype=int64)

# %%
cmd = ConfusionMatrixDisplay(cm2)
cmd.plot()
plt.show()

# %%
acc = accuracy_score(gpred,yts)
re = precision_score(gpred,yts)
rec = recall_score(gpred,yts)
f1 = f1_score(gpred,yts)
print(acc,pre,rec,f1)
# Out:
# 0.735897435897436 0.8902439024390244 0.0 0.0
# C:\Users\asus\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 due to no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %% [markdown]
# # KNN

# %%
from sklearn.neighbors import KNeighborsClassifier
knn = KNeighborsClassifier(n_neighbors=3)
knn.fit(xtr1,ytr)
# Out:
# KNeighborsClassifier(n_neighbors=3)

# %%
kpred=knn.predict(xts1)

# %%
cm3 = confusion_matrix(kpred,yts)
cm3
# Out:
# array([[486,  64],
#        [ 88, 142]], dtype=int64)

# %%
acc = accuracy_score(kpred,yts)
pre = precision_score(kpred,yts)
rec = recall_score(kpred,yts)
f1 = f1_score(kpred,yts)
print(acc,pre,rec,f1)
# Out:
# 0.8051282051282052 0.6893203883495146 0.6173913043478261 0.6513761467889908

# %% [markdown]
# # SVC

# %%
from sklearn.svm import SVC
svc = SVC(kernel='rbf',C=1000,gamma=0.04)
svc.fit(xtr1,ytr)
# Out:
# SVC(C=1000, gamma=0.04)

# %%
spred =svc.predict(xts1)

# %%
acc = accuracy_score(spred,yts)
pre = precision_score(spred,yts)
rec = recall_score(spred,yts)
f1 = f1_score(spred,yts)
print(acc,pre,rec,f1)
# Out:
# 0.8115384615384615 0.6650485436893204 0.6372093023255814 0.65083135391924
